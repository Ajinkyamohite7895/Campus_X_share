# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from pandas import Series
from pmdarima import auto_arima

# %%
series = pd.read_csv('city_day.csv')
series_delhi = series.loc[series['City'] == 'Delhi']
ts_delhi = series_delhi[['Date','AQI']]
#converting 'Date' column to type 'datetime' so that indexing can happen later
ts_delhi['Date'] = pd.to_datetime(ts_delhi['Date'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9636\476825839.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_delhi['Date'] = pd.to_datetime(ts_delhi['Date'])

# %%
ts_delhi.isnull().sum()
ts_delhi = ts_delhi.dropna()
ts_delhi.isnull().sum()
# Out:
# Date    0
# AQI     0
# dtype: int64

# %%
ts_delhi = ts_delhi.set_index('Date')

# %%
ts_month_avg = ts_delhi['AQI'].resample('MS').mean()
ts_month_avg.plot(figsize = (15, 6))
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(ts_month_avg, model='multiplicative')
fig = decomposition.plot()
plt.show()

# %%
adf_test = adfuller(ts_month_avg)

print('ADF Statistic: %f' % adf_test[0])
print('Critical Values @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistic: 0.229024
# Critical Values @ 0.05: -2.92
# p-value: 0.973843

# %%
def difference(dataset, interval=1):
 diff = list()
 for i in range(interval, len(dataset)):
     value = dataset[i] - dataset[i - interval]
     diff.append(value)
 return Series(diff)

# %%
ts_t_adj=difference(ts_month_avg)

# %%
ts_t_adj=ts_t_adj.dropna()

# %%
ts_t_adj.plot()
# Out:
# <AxesSubplot:>

# %%
adf_test = adfuller(ts_t_adj)

print('ADF Statistic: %f' % adf_test[0])
print('Critical Values @ 0.05: %.2f' % adf_test[4]['5%'])
print('p-value: %f' % adf_test[1])
# Out:
# ADF Statistic: -6.795995
# Critical Values @ 0.05: -2.92
# p-value: 0.000000

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
plot_acf(ts_t_adj,lags=25)
plot_pacf(ts_t_adj,lags=25)
plt.show()

# %%
train = ts_month_avg[0:54]
test = ts_month_avg[54:]
print('Train Timeseries Range => ', train.index.min(), ' - ' , train.index.max())
print('Test Timeseries Range => ', test.index.min(), ' - ' , test.index.max())
# Out:
# Train Timeseries Range =>  2015-01-01 00:00:00  -  2019-06-01 00:00:00
# Train Timeseries Range =>  2019-07-01 00:00:00  -  2020-07-01 00:00:00

# %%
plot_acf(ts_month_avg,lags=25)
plot_pacf(ts_month_avg,lags=25)
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

sarima = SARIMAX(train,order=(1,1,1), seasonal_order=(1,0,1,12),
                                 enforce_stationarity=False, enforce_invertibility=False,)

# %%
fitted = sarima.fit()
print(fitted.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                AQI   No. Observations:                   54
# Model:             SARIMAX(1, 1, 1)x(1, 0, 1, 12)   Log Likelihood                -202.621
# Date:                            Thu, 11 Apr 2024   AIC                            415.243
# Time:                                    12:27:18   BIC                            423.561
# Sample:                                01-01-2015   HQIC                           418.227
#                                      - 06-01-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4705      0.221      2.126      0.034       0.037       0.904
# ma.L1         -1.0000   5066.662     -0.000      1.000   -9931.474    9929.474
# ar.S.L12       0.9642      0.079     12.233      0.000       0.810       1.119
# ma.S.L12      -1.0000   5066.722     -0.000      1.000   -9931.593    9929.593
# sigma2      1118.8694      4.516    247.737      0.000    1110.017    1127.721
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.20   Jarque-Bera (JB):                 0.77
# Prob(Q):                              0.66   Prob(JB):                         0.68
# Heteroskedasticity (H):               0.62   Skew:                            -0.12
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.07e+24. Standard errors may be unstable.

# %%
pred_test = fitted.predict(start=test.index.min(), end=test.index.max())

# %%
pred_test
# Out:
# 2019-07-01    108.937050
# 2019-08-01    104.261965
# 2019-09-01    129.514668
# 2019-10-01    270.469487
# 2019-11-01    347.573554
# 2019-12-01    311.647910
# 2020-01-01    314.989298
# 2020-02-01    247.692036
# 2020-03-01    183.130572
# 2020-04-01    213.222649
# 2020-05-01    217.018175
# 2020-06-01    155.935887
# 2020-07-01     82.266482
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
plt.figure(figsize=(10,7))
plt.plot(train.index,train,label='Training Data')
plt.plot(test.index,test, label='Predictions', color='orange')
plt.legend()
plt.show()

# %%
ts_month_avg
# Out:
# Date
# 2015-01-01    342.290323
# 2015-02-01    327.928571
# 2015-03-01    256.064516
# 2015-04-01    305.266667
# 2015-05-01    348.580645
#                  ...
# 2020-03-01    135.838710
# 2020-04-01    113.000000
# 2020-05-01    148.645161
# 2020-06-01    125.733333
# 2020-07-01    101.000000
# Freq: MS, Name: AQI, Length: 67, dtype: float64

# %%
pred_future = fitted.get_prediction(start=pd.to_datetime('2020-08-01'),end=pd.to_datetime('2020-11-01') ,dynamic=False)

# %%
plt.figure(figsize=(10,7))
plt.plot(train.index,train,label='Training Data')
plt.plot(test.index,test, label='Predictions', color='orange')
plt.plot(pred_future.predicted_mean.index,pred_future.predicted_mean.values, label='Forecats', color='red')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(pred_test,test)
print(mae)
# Out:
# 32.320856069422824

# %%
test.mean()
# Out:
# 192.82541570405863

# %%
sarima_model = auto_arima(train, start_p=0, start_q=0,
                      max_p=12, max_q=12,
                      m=12,             
                      d=None,             
                      start_P=1,
                      start_Q=1,
                      max_P=10,
                      max_Q=10,
                      test='adf',         # use adftest to find optimal 'd'
                      D=None, 
                      seasonal=True,
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=False,
                         information_criterion='aic')
# Out:
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=649.483, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=624.295, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,0,0)(0,0,3)[12] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(0,0,0)(0,0,4)[12] intercept   : AIC=inf, Time=1.06 sec
#  ARIMA(0,0,0)(0,0,5)[12] intercept   : AIC=inf, Time=1.86 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : AIC=606.491, Time=0.14 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : AIC=614.981, Time=0.33 sec
#  ARIMA(0,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(0,0,0)(1,0,3)[12] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(0,0,0)(1,0,4)[12] intercept   : AIC=inf, Time=1.16 sec
#  ARIMA(0,0,0)(2,0,0)[12] intercept   : AIC=606.603, Time=0.33 sec
#  ARIMA(0,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(0,0,0)(2,0,3)[12] intercept   : AIC=inf, Time=1.20 sec
#  ARIMA(0,0,0)(3,0,0)[12] intercept   : AIC=608.722, Time=0.72 sec
#  ARIMA(0,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=0.95 sec
#  ARIMA(0,0,0)(3,0,2)[12] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(0,0,0)(4,0,0)[12] intercept   : AIC=inf, Time=2.00 sec
#  ARIMA(0,0,0)(4,0,1)[12] intercept   : AIC=inf, Time=3.54 sec
#  ARIMA(0,0,0)(5,0,0)[12] intercept   : AIC=inf, Time=2.79 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=613.859, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=605.313, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,0,1)(0,0,3)[12] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(0,0,1)(0,0,4)[12] intercept   : AIC=inf, Time=2.16 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=592.231, Time=0.32 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=593.533, Time=0.39 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(0,0,1)(1,0,3)[12] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(0,0,1)(2,0,0)[12] intercept   : AIC=586.371, Time=0.34 sec
#  ARIMA(0,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,1)(2,0,2)[12] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(0,0,1)(3,0,0)[12] intercept   : AIC=590.881, Time=0.96 sec
#  ARIMA(0,0,1)(3,0,1)[12] intercept   : AIC=inf, Time=1.09 sec
#  ARIMA(0,0,1)(4,0,0)[12] intercept   : AIC=594.999, Time=1.54 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=610.142, Time=0.11 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=603.094, Time=0.30 sec
#  ARIMA(0,0,2)(0,0,2)[12] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,2)(0,0,3)[12] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : AIC=590.551, Time=0.30 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : AIC=603.264, Time=0.39 sec
#  ARIMA(0,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : AIC=583.510, Time=0.73 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,0,2)(3,0,0)[12] intercept   : AIC=585.878, Time=0.83 sec
#  ARIMA(0,0,3)(0,0,0)[12] intercept   : AIC=602.698, Time=0.17 sec
#  ARIMA(0,0,3)(0,0,1)[12] intercept   : AIC=598.021, Time=0.19 sec
#  ARIMA(0,0,3)(0,0,2)[12] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(0,0,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(0,0,3)(1,0,1)[12] intercept   : AIC=598.625, Time=0.39 sec
#  ARIMA(0,0,3)(2,0,0)[12] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(0,0,4)(0,0,0)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,0,4)(0,0,1)[12] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(0,0,4)(1,0,0)[12] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(0,0,5)(0,0,0)[12] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=617.187, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=603.334, Time=0.19 sec
#  ARIMA(1,0,0)(0,0,2)[12] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(1,0,0)(0,0,3)[12] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(1,0,0)(0,0,4)[12] intercept   : AIC=inf, Time=1.15 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=588.727, Time=0.13 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=583.771, Time=0.33 sec
#  ARIMA(1,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(1,0,0)(1,0,3)[12] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(1,0,0)(2,0,0)[12] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(1,0,0)(2,0,2)[12] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(1,0,0)(3,0,0)[12] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(1,0,0)(3,0,1)[12] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(1,0,0)(4,0,0)[12] intercept   : AIC=inf, Time=1.50 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=608.784, Time=0.11 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=602.191, Time=0.28 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(1,0,1)(0,0,3)[12] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=590.183, Time=0.25 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=590.477, Time=0.39 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : AIC=581.377, Time=0.66 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(1,0,1)(3,0,0)[12] intercept   : AIC=584.176, Time=1.20 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=610.448, Time=0.13 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=603.502, Time=0.53 sec
#  ARIMA(1,0,2)(0,0,2)[12] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : AIC=593.117, Time=0.73 sec
#  ARIMA(1,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(1,0,2)(2,0,0)[12] intercept   : AIC=inf, Time=0.89 sec
#  ARIMA(1,0,3)(0,0,0)[12] intercept   : AIC=604.185, Time=0.31 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=599.366, Time=0.41 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(1,0,4)(0,0,0)[12] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=604.983, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=599.930, Time=0.17 sec
#  ARIMA(2,0,0)(0,0,2)[12] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(2,0,0)(0,0,3)[12] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=589.825, Time=0.39 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=596.770, Time=0.44 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : AIC=581.535, Time=0.60 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(2,0,0)(3,0,0)[12] intercept   : AIC=583.918, Time=0.85 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=604.984, Time=0.17 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=598.588, Time=0.35 sec
#  ARIMA(2,0,1)(0,0,2)[12] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=598.827, Time=0.40 sec
#  ARIMA(2,0,1)(2,0,0)[12] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=605.903, Time=0.35 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=601.060, Time=0.65 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=605.762, Time=0.58 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=606.218, Time=0.19 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=599.956, Time=0.51 sec
#  ARIMA(3,0,0)(0,0,2)[12] intercept   : AIC=inf, Time=1.22 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=590.957, Time=0.81 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=598.407, Time=0.92 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : AIC=586.090, Time=1.41 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=606.182, Time=0.59 sec
#  ARIMA(3,0,1)(0,0,1)[12] intercept   : AIC=600.583, Time=0.81 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=605.642, Time=0.86 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=606.854, Time=0.42 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=600.974, Time=0.81 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=594.058, Time=1.10 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=608.140, Time=0.68 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=608.553, Time=0.36 sec
#
# Best model:  ARIMA(1,0,1)(2,0,0)[12] intercept
# Total fit time: 81.931 seconds

# %%
print(sarima_model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   54
# Model:             SARIMAX(1, 0, 0)x(1, 0, [1], 12)   Log Likelihood                -286.885
# Date:                              Thu, 11 Apr 2024   AIC                            583.771
# Time:                                      13:22:53   BIC                            593.716
# Sample:                                  01-01-2015   HQIC                           587.606
#                                        - 06-01-2019
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      8.8532     21.818      0.406      0.685     -33.909      51.615
# ar.L1          0.6037      0.130      4.638      0.000       0.349       0.859
# ar.S.L12       0.9144      0.203      4.502      0.000       0.516       1.312
# ma.S.L12      -0.4621      0.524     -0.882      0.378      -1.489       0.565
# sigma2      2029.0913    773.659      2.623      0.009     512.748    3545.435
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.46   Jarque-Bera (JB):                 0.51
# Prob(Q):                              0.50   Prob(JB):                         0.78
# Heteroskedasticity (H):               0.68   Skew:                             0.23
# Prob(H) (two-sided):                  0.42   Kurtosis:                         3.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
auto=SARIMAX(train,order=(1,0,1), seasonal_order=(2,0,0,12),
                                 enforce_stationarity=False, enforce_invertibility=False,)

# %%
fitted_2 = auto.fit()

# %%
pred_test_new = fitted_2.predict(start=test.index.min(), end=test.index.max())

# %%
pred_test_new
# Out:
# 2019-07-01    108.844337
# 2019-08-01     92.831281
# 2019-09-01    109.412738
# 2019-10-01    253.576461
# 2019-11-01    344.016637
# 2019-12-01    316.329256
# 2020-01-01    311.472632
# 2020-02-01    242.863455
# 2020-03-01    192.742841
# 2020-04-01    206.200302
# 2020-05-01    206.039898
# 2020-06-01    187.513395
# 2020-07-01     97.168195
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
mae=mean_absolute_error(pred_test_new,test)
print(mae)
# Out:
# 30.248554644170966
